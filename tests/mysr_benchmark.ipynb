# %%
from mysr.function_generator import get_random_degrees, get_functions_for_degrees

degrees = get_random_degrees(100, 5)
functions = get_functions_for_degrees(degrees)
functions
# Out:
# [(3.0648*x + 4.3069)/(-0.286*x**5 - 1.6766*x**4 - 1.4693*x**3 + 2.2478*x**2 - 0.6234*x + 1.9051),
#  (-4.9827*x**4 - 4.9062*x**3 - 4.0633*x**2 - 0.2761*x - 4.4033)/(2.4431*x**2 + 0.2779*x + 2.6434),
#  (1.6844*x + 1.6502)/(0.1607 - 4.7535*x),
#  (-3.2435*x**2 + 1.8985*x + 3.644)/(2.3611*x**2 - 3.2293*x - 1.5867),
#  (3.2482*x + 0.3171)/(-3.5452*x**2 - 0.3647*x + 2.5841),
#  (0.3564*x**4 + 3.1389*x**3 - 0.6986*x**2 - 3.8569*x - 1.1021)/(-3.4985*x**5 + 2.8293*x**4 + 3.8128*x**3 - 1.9214*x**2 - 2.308*x - 0.4055),
#  (-4.8267*x - 0.7584)/(4.3688*x**5 - 3.4874*x**4 + 3.8249*x**3 + 2.7854*x**2 - 0.8966*x + 3.8286),
#  (-4.4717*x**2 - 4.2669*x + 2.8069)/(-2.3115*x**3 - 3.9858*x**2 + 2.1886*x + 1.7899),
#  (-1.9431*x**2 - 4.9743*x + 1.141)/(-3.2541*x**3 + 0.358*x**2 - 1.3126*x - 3.5669),
#  (3.7856*x**3 - 0.1571*x**2 + 0.885*x - 2.9477)/(1.6305*x**4 - 3.9881*x**3 + 0.8808*x**2 - 1.9443*x - 2.502),
# ...
